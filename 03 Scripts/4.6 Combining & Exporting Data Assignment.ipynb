# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Orders Products Combined Pickle File

# %%
#Creating path string
path = r'C:\Users\Alex Lam\Desktop\Career Foundary\04 Instacart Project'

# %%
#Importing prior orders dataframe
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
#Checking orders combined output
df_orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             0           0   2539329        1    prior             1
# 2             0           0   2539329        1    prior             1
# 3             0           0   2539329        1    prior             1
# 4             0           0   2539329        1    prior             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     0.0         196
# 1                   2                  8                     0.0       14084
# 2                   2                  8                     0.0       12427
# 3                   2                  8                     0.0       26088
# 4                   2                  8                     0.0       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# ...

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 13)

# %% [markdown]
# # Importing Products CSV File

# %%
#Importing prior orders dataframe
df_products = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
#Checking products output
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_products.shape
# Out:
# (49693, 5)

# %% [markdown]
# # Combining Dataframes

# %%
#The only variable the orders combined and the products datasets have in common is product_id
#I will be using product_id to combine

df_orders_products_merged = df_orders_products_combined.merge(df_products, on = 'product_id')

# %%
#Checking orders products dataframe output
df_orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           1   2398795        1    prior             2
# 2             2           2    473747        1    prior             3
# 3             3           3   2254736        1    prior             4
# 4             4           4    431534        1    prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     0.0         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
#    add_to_cart_order  reordered _merge product_name  aisle_id  department_id  \
# ...

# %%
#The number of columns is equal to one less than the total columns from each dataframe. This value means the two dataframes properly combined.
df_orders_products_merged.shape
# Out:
# (32434212, 17)

# %%
#Testing merge without overwriting
pd.merge(df_orders_products_combined, df_products, on = 'product_id', indicator = 'Check')
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                    0           0   2539329        1    prior             1
# 1                    1           1   2398795        1    prior             2
# 2                    2           2    473747        1    prior             3
# 3                    3           3   2254736        1    prior             4
# 4                    4           4    431534        1    prior             5
# ...                ...         ...       ...      ...      ...           ...
# 32434207       3360493     3360493   1320836   202557    prior            17
# 32434208       3360494     3360494     31526   202557    prior            18
# 32434209       3376038     3376038    758936   203436    prior             1
# 32434210       3376039     3376039   2745165   203436    prior             2
# 32434211       3408036     3408036   3093936   205420    prior             1
#
# ...

# %%
# Export data to pkl

df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))

# %%
# Export data to csv

df_orders_products_merged.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.csv'))
